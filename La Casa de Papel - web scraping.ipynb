# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url = "https://en.wikipedia.org/wiki/List_of_Money_Heist_episodes"
data= requests.get(url)

# %%
soup= BeautifulSoup(data.text, "html.parser")

# %%
print("All the tables on the page:" , len(soup.findAll("table")))
# Out:
# All the tables on the page: 5

# %%
title= soup.title
print(title)
# Out:
# <title>List of Money Heist episodes - Wikipedia</title>

# %%
text= soup.get_text()
print(text)
#This gives us all the text on the webpage
# Out:
# List of Money Heist episodes - Wikipedia
# ...

# %%
my_table= soup.findAll("table")[0]
my_table
# Out:
# <table class="wikitable plainrowheaders" style="text-align:center"><caption><style data-mw-deduplicate="TemplateStyles:r966338595">.mw-parser-output .sr-only{border:0;height:1px;width:1px;top:auto;padding:0;margin:-1px;left:-10000px;overflow:hidden;position:absolute;clip:rect(0,0,0,0)}</style><span class="sr-only">Overview of <i>Money Heist</i> seasons</span></caption><tbody><tr style="text-align:center"><th colspan="2" rowspan="2" scope="col" style="min-width:50px;padding:0 8px">Season<sup class="reference" id="cite_ref-SeasonPart_2-1"><a href="#cite_note-SeasonPart-2">[b]</a></sup></th><th rowspan="2" scope="col" style="padding:0 8px">Part<sup class="reference" id="cite_ref-SeasonPart_2-2"><a href="#cite_note-SeasonPart-2">[b]</a></sup></th><th colspan="2" rowspan="2" scope="col" style="padding:0 8px">Episodes</th><th colspan="3" scope="col">Originally released</th></tr><tr><th scope="col">First released</th><th scope="col">Last released</th><th scope="col" style="padding:0 8px">Ne
# ...

# %%
oly_codes = ['No.overall', 'No. in season', 'Title', 'Written by']

# %%
tables = pd.read_html(url)
tables
# Out:
# [  Season[b]             Part[b] Episodes            Originally released  \
#    Season[b] Season[b].1 Part[b] Episodes Episodes.1      First released
#  0       NaN           1       1    15[a]          9          2 May 2017
#  1       NaN           1       2    15[a]          6     16 October 2017
#  2       NaN           2       3       16          8        19 July 2019
#  3       NaN           2       4       16          8        3 April 2020
#
#
#        Last released   Network
#  0      27 June 2017  Antena 3
#  1  23 November 2017  Antena 3
#  2      19 July 2019   Netflix
#  3      3 April 2020   Netflix  ,
#                                             No.overall  \
#  0                                              Part 1
#  1                                                   1
#  2   In the aftermath of a failed bank robbery by a...
#  3                                                   2
#  4   The robbers begin to print the money while Art...
# ...

# %%
df = tables[1]
df
# Out:
#                                            No.overall  \
# 0                                              Part 1
# 1                                                   1
# 2   In the aftermath of a failed bank robbery by a...
# 3                                                   2
# 4   The robbers begin to print the money while Art...
# 5                                                   3
# 6   Believing that Denver executed Mónica under Be...
# 7                                                   4
# 8   Raquel sends her police partner Ángel Rubio in...
# 9                                                   5
# 10  The Professor runs ahead of the police to get ...
# 11                                                  6
# 12  As the Professor rushes out of the scrap yard,...
# 13                                                  7
# 14  The robbers initiate a plan to use the hostage...
# 15                                                  8
# ...

# %%
df
# Out:
#                                            No.overall  \
# 0                                              Part 1
# 1                                                   1
# 2   In the aftermath of a failed bank robbery by a...
# 3                                                   2
# 4   The robbers begin to print the money while Art...
# 5                                                   3
# 6   Believing that Denver executed Mónica under Be...
# 7                                                   4
# 8   Raquel sends her police partner Ángel Rubio in...
# 9                                                   5
# 10  The Professor runs ahead of the police to get ...
# 11                                                  6
# 12  As the Professor rushes out of the scrap yard,...
# 13                                                  7
# 14  The robbers initiate a plan to use the hostage...
# 15                                                  8
# ...

# %%
df.drop(['Unnamed: 7' ,'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10' ,'Unnamed: 11','Unnamed: 12'], 1, inplace=True)

# %%
df.columns = ['No.overall', 'No. inseason', 'Title', 'Directed by','Written by','Original air date','Spain viewers(millions)']
df
# Out:
#                                            No.overall  \
# 0                                              Part 1
# 1                                                   1
# 2   In the aftermath of a failed bank robbery by a...
# 3                                                   2
# 4   The robbers begin to print the money while Art...
# 5                                                   3
# 6   Believing that Denver executed Mónica under Be...
# 7                                                   4
# 8   Raquel sends her police partner Ángel Rubio in...
# 9                                                   5
# 10  The Professor runs ahead of the police to get ...
# 11                                                  6
# 12  As the Professor rushes out of the scrap yard,...
# 13                                                  7
# 14  The robbers initiate a plan to use the hostage...
# 15                                                  8
# ...

# %%
tables = pd.read_html(url)
tables
# Out:
# [  Season[b]             Part[b] Episodes            Originally released  \
#    Season[b] Season[b].1 Part[b] Episodes Episodes.1      First released
#  0       NaN           1       1    15[a]          9          2 May 2017
#  1       NaN           1       2    15[a]          6     16 October 2017
#  2       NaN           2       3       16          8        19 July 2019
#  3       NaN           2       4       16          8        3 April 2020
#
#
#        Last released   Network
#  0      27 June 2017  Antena 3
#  1  23 November 2017  Antena 3
#  2      19 July 2019   Netflix
#  3      3 April 2020   Netflix  ,
#                                             No.overall  \
#  0                                              Part 1
#  1                                                   1
#  2   In the aftermath of a failed bank robbery by a...
#  3                                                   2
#  4   The robbers begin to print the money while Art...
# ...

# %%
df = tables[2]
df
# Out:
#                                            No.overall  \
# 0                                              Part 3
# 1                                                  16
# 2   Over two years after the heist, Arturo gives a...
# 3                                                  17
# 4   The Professor initiates the plan to rob the Ba...
# 5                                                  18
# 6   While commandeering the Bank, the robbers enga...
# 7                                                  19
# 8   The crew begins the next phase of the robbery ...
# 9                                                  20
# 10  A love interest between Palermo and Helsinki i...
# 11                                                 21
# 12  In flashbacks, the Professor discusses the pla...
# 13                                                 22
# 14  Sierra prepares Rio for release at a military ...
# 15                                                 23
# ...

# %%
df.drop(['Unnamed: 7' ,'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10' ,'Unnamed: 11','Unnamed: 12'], 1, inplace=True)

# %%
df.columns = ['No.overall', 'No. inseason', 'Title', 'Directed by','Written by','Original air date','Spain viewers(millions)']
df
# Out:
#                                            No.overall  \
# 0                                              Part 3
# 1                                                  16
# 2   Over two years after the heist, Arturo gives a...
# 3                                                  17
# 4   The Professor initiates the plan to rob the Ba...
# 5                                                  18
# 6   While commandeering the Bank, the robbers enga...
# 7                                                  19
# 8   The crew begins the next phase of the robbery ...
# 9                                                  20
# 10  A love interest between Palermo and Helsinki i...
# 11                                                 21
# 12  In flashbacks, the Professor discusses the pla...
# 13                                                 22
# 14  Sierra prepares Rio for release at a military ...
# 15                                                 23
# ...
